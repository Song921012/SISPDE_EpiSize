# %%
using DifferentialEquations, ModelingToolkit, MethodOfLines, DomainSets, Plots, NLsolve, Sundials, LoopVectorization, Polyester
using Integrals
using QuadGK
# Out:
# ┌ Info: Precompiling DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# └ @ Base loading.jl:1662
# ERROR: LoadError: UndefVarError: Dynamic not defined
# Stacktrace:
#  [1] include
#    @ ./Base.jl:419 [inlined]
#  [2] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt64}}, source::String)
#    @ Base ./loading.jl:1554
#  [3] top-level scope
#    @ stdin:1
# in expression starting at /home/aidishage/.julia/packages/StaticArrays/NOLon/src/StaticArrays.jl:1
# in expression starting at stdin:1
# ERROR: LoadError: Failed to precompile StaticArrays [90137ffa-7385-5640-81b9-e52037218182] to /home/aidishage/.julia/compiled/v1.8/StaticArrays/jl_zhGeqp.
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:1705
#   [3] compilecache
#     @ ./loading.jl:1649 [inlined]
#   [4] _require(pkg::Base.PkgId)
#     @ Base ./loading.jl:1337
#   [5] _require_prelocked(uuidkey::Base.PkgId)
#     @ Base ./loading.jl:1200
#   [6] macro expansion
#     @ ./loading.jl:1180 [inlined]
#   [7] macro expansion
#     @ ./lock.jl:223 [inlined]
#   [8] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1144
#   [9] include
#     @ ./Base.jl:419 [inlined]
#  [10] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt64}}, source::String)
#     @ Base ./loading.jl:1554
#  [11] top-level scope
#     @ stdin:1
# in expression starting at /home/aidishage/.julia/packages/DiffEqBase/5rKYk/src/DiffEqBase.jl:1
# in expression starting at stdin:1
# ERROR: LoadError: Failed to precompile DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] to /home/aidishage/.julia/compiled/v1.8/DiffEqBase/jl_KF2kSf.
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:1705
#   [3] compilecache
#     @ ./loading.jl:1649 [inlined]
#   [4] _require(pkg::Base.PkgId)
#     @ Base ./loading.jl:1337
#   [5] _require_prelocked(uuidkey::Base.PkgId)
#     @ Base ./loading.jl:1200
#   [6] macro expansion
#     @ ./loading.jl:1180 [inlined]
#   [7] macro expansion
#     @ ./lock.jl:223 [inlined]
#   [8] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1144
#   [9] include
#     @ ./Base.jl:419 [inlined]
#  [10] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt64}}, source::Nothing)
#     @ Base ./loading.jl:1554
#  [11] top-level scope
#     @ stdin:1
# in expression starting at /home/aidishage/.julia/packages/DifferentialEquations/VkYkb/src/DifferentialEquations.jl:1
# in expression starting at stdin:1
# Failed to precompile DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa] to /home/aidishage/.julia/compiled/v1.8/DifferentialEquations/jl_Dss6Kp.
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:1705
#   [3] compilecache
#     @ ./loading.jl:1649 [inlined]
#   [4] _require(pkg::Base.PkgId)
#     @ Base ./loading.jl:1337
#   [5] _require_prelocked(uuidkey::Base.PkgId)
#     @ Base ./loading.jl:1200
#   [6] macro expansion
#     @ ./loading.jl:1180 [inlined]
#   [7] macro expansion
#     @ ./lock.jl:223 [inlined]
#   [8] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1144
#   [9] eval
#     @ ./boot.jl:368 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1428

# %%
using DifferentialEquations
# Out:
# ┌ Info: Precompiling DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# └ @ Base loading.jl:1662
# ERROR: LoadError: UndefVarError: Dynamic not defined
# Stacktrace:
#  [1] include
#    @ ./Base.jl:419 [inlined]
#  [2] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt64}}, source::String)
#    @ Base ./loading.jl:1554
#  [3] top-level scope
#    @ stdin:1
# in expression starting at /home/aidishage/.julia/packages/StaticArrays/NOLon/src/StaticArrays.jl:1
# in expression starting at stdin:1
# ERROR: LoadError: Failed to precompile StaticArrays [90137ffa-7385-5640-81b9-e52037218182] to /home/aidishage/.julia/compiled/v1.8/StaticArrays/jl_EU9Smj.
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:1705
#   [3] compilecache
#     @ ./loading.jl:1649 [inlined]
#   [4] _require(pkg::Base.PkgId)
#     @ Base ./loading.jl:1337
#   [5] _require_prelocked(uuidkey::Base.PkgId)
#     @ Base ./loading.jl:1200
#   [6] macro expansion
#     @ ./loading.jl:1180 [inlined]
#   [7] macro expansion
#     @ ./lock.jl:223 [inlined]
#   [8] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1144
#   [9] include
#     @ ./Base.jl:419 [inlined]
#  [10] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt64}}, source::String)
#     @ Base ./loading.jl:1554
#  [11] top-level scope
#     @ stdin:1
# in expression starting at /home/aidishage/.julia/packages/DiffEqBase/5rKYk/src/DiffEqBase.jl:1
# in expression starting at stdin:1
# ERROR: LoadError: Failed to precompile DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] to /home/aidishage/.julia/compiled/v1.8/DiffEqBase/jl_xBrOSR.
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:1705
#   [3] compilecache
#     @ ./loading.jl:1649 [inlined]
#   [4] _require(pkg::Base.PkgId)
#     @ Base ./loading.jl:1337
#   [5] _require_prelocked(uuidkey::Base.PkgId)
#     @ Base ./loading.jl:1200
#   [6] macro expansion
#     @ ./loading.jl:1180 [inlined]
#   [7] macro expansion
#     @ ./lock.jl:223 [inlined]
#   [8] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1144
#   [9] include
#     @ ./Base.jl:419 [inlined]
#  [10] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt64}}, source::Nothing)
#     @ Base ./loading.jl:1554
#  [11] top-level scope
#     @ stdin:1
# in expression starting at /home/aidishage/.julia/packages/DifferentialEquations/VkYkb/src/DifferentialEquations.jl:1
# in expression starting at stdin:1
# Failed to precompile DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa] to /home/aidishage/.julia/compiled/v1.8/DifferentialEquations/jl_M9vTvE.
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:1705
#   [3] compilecache
#     @ ./loading.jl:1649 [inlined]
#   [4] _require(pkg::Base.PkgId)
#     @ Base ./loading.jl:1337
#   [5] _require_prelocked(uuidkey::Base.PkgId)
#     @ Base ./loading.jl:1200
#   [6] macro expansion
#     @ ./loading.jl:1180 [inlined]
#   [7] macro expansion
#     @ ./lock.jl:223 [inlined]
#   [8] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1144
#   [9] eval
#     @ ./boot.jl:368 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1428
